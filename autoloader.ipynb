# %%
spark.sql("create volume if not exists external.new.schema1")

# %%
check_point=f'/Volumes/external/new/schema'

# %%
(spark.readStream.format("cloudfiles").option("cloudFiles.format", 'csv').option("header", "true").option("inferSchema", "false").option("cloudFiles.schemaLocation", check_point).load(f"/Volumes/external/new/cloudefile").
writeStream.option("checkpointLocation", check_point).trigger(once=True).table("external.new.cloudfilenew"))

# %%
# %sql
select count(*) from external.new.cloudfilenew

# %%
df=spark.read.csv('abfss://rawfiles@slave3000.dfs.core.windows.net/csvfiles/Calendar.csv',header=True)

# %%
check_point1=f'/Volumes/external/new/schema1'

# %%
spark.readStream.format("cloudfiles") \
    .option("cloudFiles.format", "csv") \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .option("cloudFiles.schemaLocation", check_point1) \
    .load("abfss://rawfiles@slave3000.dfs.core.windows.net/autoloader") \
    .writeStream \
    .option("checkpointLocation", check_point1) \
    .trigger(processingTime="10 seconds") \
    .table("external.new.cloudfilenew1")

# %%
# %sql
select count(*) from external.new.cloudfilenew1
